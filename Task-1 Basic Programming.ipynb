# %%
if __name__ == '__main__':
    print("Hello, World!")
# Out:
# Hello, World!

# %%
if __name__ == '__main__':
    n = int(input().strip())
    if n%2!=0:
        print("Weird")
    else:
        if 2<=n<=5:
            print("Not Weird")
        elif 6<=n<=20:
            print("Weird")
        else:
            print("Not Weird")
# Out:
#  5
# Weird

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a+b)
    print(a-b)
    print(a*b)
# Out:
#  3
#  2
# 5
# 1
# 6

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input()) 
    print(a//b)
    print(a/b)
# Out:
#  4
#  3
# 1
# 1.3333333333333333

# %%
#squares in given range
if __name__ == '__main__':
    n = int(input())
    for i in range(0,n):
        s=i*i
        print(s)
# Out:
#  3
# 0
# 1
# 4

# %%
#leap year
def is_leap(year):
    leap = False
    
    if year%4==0 and year%100!=0:
        leap=True
    elif year%400==0:
        leap=True
    
    return leap

year = int(input())
print(is_leap(year))
# Out:
#  2004
# True

# %%
if __name__ == '__main__':
    n = int(input())
    s=''
    for i in range(1,n+1):
        s+=str(i)
    print(s)
# Out:
#  4
# 1234
